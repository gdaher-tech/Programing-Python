# %% [markdown]
#  ## Em grupos, crie um script Python que implementa uma Unidade Lógica Aritmética (ULA) simples. Para essa ULA, escolham 2 operações aritméticas, 2 operações lógicas e 1 operação de deslocamento, para ser implementado. Crie um exemplo que parta de 2 números decimais

# %% [markdown]
# ## Alunos:
# - Gustavo (25101039)
# - Rafael (2221150)
# - Larissa (2311050)
# - João Eduardo (2311236)

# %%
numero1 = float(input('Digite o primeiro número decimal: '))
numero2 = float(input('Digite o segundo número decimal: '))

# ----- PRIMEIRA OPERAÇÃO ARITMÉTICA -----
print("\n[1ª OPERAÇÃO ARITMÉTICA OBRIGATÓRIA]")
print("Escolha uma operação para realizar entre os números:")
print(" 1 - Adição")
print(" 2 - Subtração")
print(" 3 - Divisão")
print(" 4 - Multiplicação")
opcao1 = input("Digite o número da operação desejada: ")

if opcao1 == '1':
    resultado1 = numero1 + numero2
    operacao1 = "Adição"
elif opcao1 == '2':
    resultado1 = numero1 - numero2
    operacao1 = "Subtração"
elif opcao1 == '3':
    if numero2 != 0:
        resultado1 = numero1 / numero2
        operacao1 = "Divisão"
    else:
        print("Erro: divisão por zero.")
        exit()
elif opcao1 == '4':
    resultado1 = numero1 * numero2
    operacao1 = "Multiplicação"
else:
    print("Opção inválida. Encerrando programa.")
    exit()

print(f"\n✅ Resultado da 1ª operação ({operacao1}): {resultado1:.2f}")

# ----- SEGUNDA OPERAÇÃO ARITMÉTICA -----
print("\n[2ª OPERAÇÃO ARITMÉTICA OBRIGATÓRIA]")
print("Escolha outra operação para realizar com os mesmos números:")
print(" 1 - Adição")
print(" 2 - Subtração")
print(" 3 - Divisão")
print(" 4 - Multiplicação")
opcao2 = input("Digite o número da nova operação: ")

if opcao2 == '1':
    resultado2 = numero1 + numero2
    operacao2 = "Adição"
elif opcao2 == '2':
    resultado2 = numero1 - numero2
    operacao2 = "Subtração"
elif opcao2 == '3':
    if numero2 != 0:
        resultado2 = numero1 / numero2
        operacao2 = "Divisão"
    else:
        print("Erro: divisão por zero.")
        exit()
elif opcao2 == '4':
    resultado2 = numero1 * numero2
    operacao2 = "Multiplicação"
else:
    print("Opção inválida. Encerrando programa.")
    exit()

print(f"\n✅ Resultado da 2ª operação ({operacao2}): {resultado2:.2f}")

# ----- OPERAÇÃO DE DESLOCAMENTO COM << e OR -----
print("\n[OPERAÇÃO FINAL OBRIGATÓRIA - DESLOCAMENTO BIT A BIT]")

n1 = int(numero1)
n2 = int(numero2)

shift_n1 = n1 << 1
shift_n2 = n2 << 1
deslocamento = shift_n1 | shift_n2

print(f"""
➡️  Deslocamento à esquerda:
    {n1} << 1 = {shift_n1}
    {n2} << 1 = {shift_n2}

➡️  Operação final com OR:
    {shift_n1} | {shift_n2} = {deslocamento}

🧠 Representação em binário:
    {bin(shift_n1)} | {bin(shift_n2)} = {bin(deslocamento)}
""")
# Out:
# [1ª OPERAÇÃO ARITMÉTICA OBRIGATÓRIA]
# Escolha uma operação para realizar entre os números:
#  1 - Adição
#  2 - Subtração
#  3 - Divisão
#  4 - Multiplicação
#
# ✅ Resultado da 1ª operação (Subtração): -4.00
#
# [2ª OPERAÇÃO ARITMÉTICA OBRIGATÓRIA]
# Escolha outra operação para realizar com os mesmos números:
#  1 - Adição
#  2 - Subtração
#  3 - Divisão
#  4 - Multiplicação
#
# ✅ Resultado da 2ª operação (Adição): 24.00
#
# [OPERAÇÃO FINAL OBRIGATÓRIA - DESLOCAMENTO BIT A BIT]
#
# ➡️  Deslocamento à esquerda:
#     10 << 1 = 20
#     14 << 1 = 28
#
# ➡️  Operação final com OR:
#     20 | 28 = 28
#
# 🧠 Representação em binário:
#     0b10100 | 0b11100 = 0b11100
